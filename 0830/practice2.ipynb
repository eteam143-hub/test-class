# %%
# Out:
#   Cell In[11], line 2
#     import random
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
while(True):
    play_game()
    is_play = input("你還要玩嗎?(y,n)")
    if is_play.upper() == "N":
        break;
print("遊戲結束")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 while(True):
# ----> 2     play_game()
#       3     is_play = input("你還要玩嗎?(y,n)")
#       4     if is_play.upper() == "N":
#       5         break;
#
# NameError: name 'play_game' is not defined
