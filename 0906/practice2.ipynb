# %%
class Person:
    def __init__(self,name:str):
        self.name = name

# %%
p1:Person = Person("jenny") #位置呼叫
p2:Person = Person(name="robert") # 名稱呼叫

print(p1.name)
print(p2.name)
# Out:
# jenny
# robert
