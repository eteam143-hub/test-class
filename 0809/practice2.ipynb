# %%
from google import genai
from dotenv import load_dotenv

load_dotenv()

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="天空為什麼是藍的"
)

print(interaction.output_text)
# Out:
# 天空之所以是藍色的，主要是因為一個物理現象，叫做**「瑞立散射」（Rayleigh scattering）**。這可以拆解為三個主要原因：
#
# ### 1. 太陽光是由七彩組成的
# 太陽光看起來是白色的，但實際上它是由紅、橙、黃、綠、藍、靛、紫等各種顏色的光混合而成的（就像彩虹的顏色）。這些光以「波」的形式傳播：
# *   **紅光、橙光**：波長較**長**。
# *   **藍光、紫光**：波長較**短**。
#
# ### 2. 大氣層的「阻擋」與「散射」
# 地球周圍包圍著厚厚的大氣層，裡面充滿了無數的氮氣和氧氣分子。
# *   當太陽光穿過大氣層時，波長較長的光（如紅光）穿透力強，可以直接穿透大氣層，直達地面。
# *   但是，波長較短的**藍光**在遇到微小的氣體分子時，很容易被撞擊並向四面八方「散射」（亂跑亂飛）。
# *   當我們抬頭看天空時，這些被散射的藍光充斥在整個天空中，進到我們的眼睛裡，所以天空看起來就是藍色的。
#
# ### 3. 為什麼天空不是「紫色」的？
# 這是一個非常聰明的問題。因為紫光的波長比藍光還要短，照理說紫光的散射應該更嚴重，天空為什麼不是紫色的？
# 主要有兩個原因：
# 1.  **太陽光的成份**：太陽放射出來的光線中，藍光的強度本來就比紫光強很多。
# 2.  **人類眼睛的構造**：人類眼睛的視網膜上有感知顏色的細胞（錐狀細胞），我們對**藍色、綠色和紅色**特別敏感，但對紫光的敏感度很低。因此，即使天空中混雜著藍光與紫光，我們的大腦也會自動把天空解讀為「藍色」。
#
# ---
#
# ### 💡 延伸思考：那為什麼「夕陽」是紅色的？
# 在傍晚或清晨時，太陽位置很低，太陽光需要穿過**比中午厚很多**的大氣層才能到達我們的眼睛。
# 在這個過程中，藍光因為一路上不斷被散射，在到達我們眼睛之前就已經被「散光了」；而穿透力最強的**紅光、橙光**則能突破重圍到達我們的眼睛，所以夕陽看起來就是美麗的紅橘色。
