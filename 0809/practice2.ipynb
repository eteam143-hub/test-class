# %%
from google import genai
from dotenv import load_dotenv

load_dotenv()

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="天空為什麼是藍的"
)

print(interaction.output_text)
# Out:
# 天空之所以是藍色的，主要是因為**太陽光**與**地球大氣層**產生的交互作用，這個科學現象被稱為「**瑞利散射**」（Rayleigh scattering）。
#
# 我們可以把這個過程拆解成三個簡單的步驟來理解：
#
# ### 1. 太陽光其實是「彩虹色」的
# 雖然太陽光看起來是白色的，但它其實包含了紅、橙、黃、綠、藍、靛、紫等所有彩虹的顏色。這些不同顏色的光以「波」的形式傳播，並且各有不同的**波長**：
# *   **紅光、黃光**：波長較**長**。
# *   **藍光、紫光**：波長較**短**。
#
# ### 2. 大氣層的「篩選」作用（瑞利散射）
# 地球周圍包圍著厚厚的大氣層，裡面充滿了氣體分子（主要是氮氣和氧氣）。
# 當太陽光射入大氣層時，會與這些微小的氣體分子碰撞：
# *   波長較長的光（如紅光、黃光）穿透力強，能直接穿過大氣分子，直達地面。
# *   波長較短的光（如藍光、紫光）遇到微小的氣體分子時，就會像彈珠碰到障礙物一樣，**向四面八方散射開來**。這種現象就是「瑞利散射」。
# *   因為藍光在天空中被無數次地散射，填滿了整個天空，所以我們抬頭看時，就會看到一片藍色。
#
# ### 3. 為什麼天空不是「紫色」的？
# 你可能會問：**紫光的波長比藍光更短，散射得更厲害，那天空為什麼不是紫色的？**
#
# 這有兩個主要原因：
# 1.  **太陽光的成分**：太陽放射出的光芒中，藍光的比例本來就比紫光多很多。
# 2.  **人類眼睛的構造**：人類眼睛的視網膜上有三種辨色細胞（紅、綠、藍）。我們的眼睛對**藍色**比對紫色敏感得多。因此，即使天空中混雜著紫光，我們的大腦接收到的信號依然會呈現出美麗的藍色。
#
# ---
#
# ### 補充小知識：為什麼傍晚的夕陽是紅色的？
# 在日出或日落時，太陽的位置很低，陽光必須**斜斜地穿過更厚的大氣層**才能到達我們的眼睛。
# 在這個漫長的過程中，波長較短的藍光在半路上就被散射殆盡了，只剩下穿透力最強的**紅光、橙光**能夠成功抵達我們的眼睛，所以夕陽才會呈現美麗的橘紅色。
